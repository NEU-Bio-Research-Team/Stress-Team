# %%
import pandas as pd

# %%
df_raw = pd.read_csv("data/processed/tardis/confounder_outputs/Event_Dynamics_100ms_gridded.csv")
df_grid = pd.read_csv("data/processed/tardis/confounder_outputs/Event_Dynamics_100ms.csv")

# %%
df_raw.columns
# Out:
# Index(['timestamp_ms', 'event_id', 'date', 'timestamp_utc',
#        'time_from_drop_start_ms', 'phase', 'close', 'ofi', 'trade_intensity',
#        'volume', 'dollar_volume', 'buy_ratio', 'vwap', 'log_return',
#        'amihud_illiq', 'kyle_lambda', 'vpin', 'realized_vol_50',
#        'leverage_proxy', 'order_flow_toxicity', 'realized_vol_10',
#        'realized_vol_200', 'ofi_autocorr_20', 'velocity_pct_per_100ms',
#        'drop_velocity_pct_per_100ms', 'panic_acceleration_pct_per_100ms2',
#        'drop_1s_pct', 'drop_from_local_pct', 'recovery_eta',
#        'delta_from_news_ms'],
#       dtype='str')

# %%
df_grid.columns
# Out:
# Index(['event_id', 'date', 'timestamp_ms', 'timestamp_utc',
#        'time_from_drop_start_ms', 'phase', 'close', 'ofi', 'trade_intensity',
#        'volume', 'dollar_volume', 'buy_ratio', 'vwap', 'log_return',
#        'amihud_illiq', 'kyle_lambda', 'vpin', 'realized_vol_50',
#        'leverage_proxy', 'order_flow_toxicity', 'realized_vol_10',
#        'realized_vol_200', 'ofi_autocorr_20', 'velocity_pct_per_100ms',
#        'drop_velocity_pct_per_100ms', 'panic_acceleration_pct_per_100ms2',
#        'drop_1s_pct', 'drop_from_local_pct', 'recovery_eta',
#        'delta_from_news_ms'],
#       dtype='str')
